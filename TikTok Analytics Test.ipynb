# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Import pandas
import pandas as pd

# %%
# Reading the initial JSON object
df = pd.read_json(path_or_buf = 'export.json')

# View the first 5 rows
df.head()
# Out:
#                     id                                               desc  \
# 0  6914157190987271168  Oh Julius 😅 "Julius the Python" on YouTube #ju...
# 1  6909838234151422976  stain.. Petit python banana..😍#fyp  #ballpytho...
# 2  6958430060340694016  Happy birthday little buddy 🐍 #snake #python #...
# 3  6980527845726604288  lil too busy worried about snacks.. #Python #d...
# 4  6840796191161175040  Check out this baby python! Did you kno their ...
#
#    createTime                                              video  \
# 0  1609827712  {'id': '6914157190987271430', 'height': 480, '...
# 1  1608822085  {'id': '6909838234151423234', 'height': 960, '...
# 2  1620135755  {'id': '6958430060340694278', 'height': 1024, ...
# 3  1625280797  {'id': '6980527845726604549', 'height': 1024, ...
# 4  1592746983  {'id': '6840796191161175302', 'height': 1024, ...
#
#                                               author  \
# 0  {'id': '6815401436291580934', 'uniqueId': '666...
# 1  {'id': '6879407363858793478', 'uniqueId': 'ale...
# 2  {'id': '6700343527676740613', 'uniqueId': 'the...
# 3  {'id': '6797473463524148230', 'uniqueId': 'cac...
# 4  {'id': '6699542567460389894', 'uniqueId': 'jay...
#
#                                                music  \
# 0  {'id': '6914157155620801286', 'title': 'origin...
# 1  {'id': '6623108046656637701', 'title': 'Follow...
# 2  {'id': '6800370585814697986', 'title': 'Intent...
# 3  {'id': '6980527635675745029', 'title': 'origin...
# 4  {'id': '6754296561716447233', 'title': 'Roses ...
#
#                                           challenges  \
# 0  [{'id': '1688028247347206', 'title': 'juliusth...
# 1  [{'id': '229207', 'title': 'fyp', 'desc': '', ...
# 2  [{'id': '37769', 'title': 'snake', 'desc': 'Il...
# 3  [{'id': '163195', 'title': 'python', 'desc': '...
# 4  [{'id': '1597138111108097', 'title': 'animalso...
#
#                                                stats             duetInfo  \
# 0  {'diggCount': 3500000, 'shareCount': 271600, '...  {'duetFromId': '0'}
# 1  {'diggCount': 2600000, 'shareCount': 36900, 'c...  {'duetFromId': '0'}
# 2  {'diggCount': 2200000, 'shareCount': 16400, 'c...  {'duetFromId': '0'}
# 3  {'diggCount': 1900000, 'shareCount': 38200, 'c...  {'duetFromId': '0'}
# 4  {'diggCount': 1900000, 'shareCount': 15500, 'c...  {'duetFromId': '0'}
#
#    originalItem  ...  privateItem duetEnabled  stitchEnabled  shareEnabled  \
# 0         False  ...        False        True           True          True
# 1         False  ...        False       False          False          True
# 2         False  ...        False       False          False          True
# 3         False  ...        False        True           True          True
# 4         False  ...        False        True           True          True
#
#                                       stickersOnItem   isAd  duetDisplay  \
# 0  [{'stickerType': 4, 'stickerText': ['That time...  False            0
# 1                                                NaN  False            0
# 2                                                NaN  False            0
# 3  [{'stickerType': 9, 'stickerText': ['Dog steps...  False            0
# 4                                                NaN  False            0
#
#    stitchDisplay  warnInfo effectStickers
# 0              0       NaN            NaN
# 1              0       NaN            NaN
# 2              0       NaN            NaN
# 3              0       NaN            NaN
# 4              0       NaN            NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# # Create Helper Function to Process Data

# %%
# Import json library to load export .json
import json

# %%
# Load up the data
with open('export.json', 'r') as f:
    data = json.load(f)

# %%
nested_values = ['video', 'author', 'music', 'stats', 'authorStats', 'challenges', 'duetInfo', 'textExtra']
skip_values = ['challenges', 'duetInfo', 'textExtra', 'stickersOnItem']

# %%
# Create a blank dictionary
flattened_data = {}

# Loop through each video
for idx, value in enumerate(data):
    flattened_data[idx] = {}
    
    # Loop through each property in each video
    for prop_idx, prop_value in value.items():
        
        # Check if nested
        if prop_idx in nested_values:
            if prop_idx in skip_values:
                pass
            else:
                # Loop through each nested property
                for nested_idx, nested_value in prop_value.items():
                    flattened_data[idx][prop_idx + '_' + nested_idx] = nested_value
        # If it's not nested, add it back to the flattened dictionary
        else:
            flattened_data[idx][prop_idx] = prop_value

# %%
flattened_data
# Out:
# {0: {'id': '6914157190987271430',
#   'desc': 'Oh Julius 😅 "Julius the Python" on YouTube #juliusthesnake #python #snakes #petsnakes #reptiles #bigsnakes #exoticpet #burmesepython #funnyanimals',
#   'createTime': 1609827712,
#   'video_id': '6914157190987271430',
#   'video_height': 480,
#   'video_width': 640,
#   'video_duration': 9,
#   'video_ratio': '480p',
#   'video_cover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/f8b44ab15bd64f4ba820bc477f485a10_1609827713?x-expires=1642528800&x-signature=hyeimXP3MrVHFlmFXKbKSk1EY0g%3D',
#   'video_originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/41cd16b79320490bbd12e6f5f3d9b06a_1609827713?x-expires=1642528800&x-signature=QHY3zqiHZ9yKylypkbB%2BZP0Kh94%3D',
#   'video_dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/ec2039a008c24b859c00aa3aa3971c9c_1609827714?x-expires=1642528800&x-signature=1qDu7IvVYZxtTUhSrtOh1sOHFuQ%3D',
#   'video_playAddr': 'https://v16-webapp.tiktok.com/05520af57f555725d67bd323ab948855/61e709c6/video/tos/useast2a/tos-useast2a-ve-0068c001/027aa7b9454044f98520401bbb5eaf44/?a=1988&br=816&bt=408&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=2&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=ajV1eXNtNXkzeTMzNTczM0ApNDo8OmY0Mzs3N2lkOzhnZGduNHM2NDAwXm5fLS1fMTZzczIzYy9iYDAyMTJgNjYwYWM6Yw%3D%3D&vl=&vr=',
#   'video_downloadAddr': 'https://v16-webapp.tiktok.com/05520af57f555725d67bd323ab948855/61e709c6/video/tos/useast2a/tos-useast2a-ve-0068c001/027aa7b9454044f98520401bbb5eaf44/?a=1988&br=816&bt=408&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=2&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=ajV1eXNtNXkzeTMzNTczM0ApNDo8OmY0Mzs3N2lkOzhnZGduNHM2NDAwXm5fLS1fMTZzczIzYy9iYDAyMTJgNjYwYWM6Yw%3D%3D&vl=&vr=',
#   'video_shareCover': ['',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/41cd16b79320490bbd12e6f5f3d9b06a_1609827713~tplv-tiktok-play.jpeg?x-expires=1643112000&x-signature=jYAYinsXoQrSoSl6o2HHkmeelRU%3D',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/41cd16b79320490bbd12e6f5f3d9b06a_1609827713~tplv-tiktokx-share-play.jpeg?x-expires=1643112000&x-signature=cTpC7UFaLSBJoQQtSo59C0nwZaw%3D'],
#   'video_reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/f8b44ab15bd64f4ba820bc477f485a10_1609827713?x-expires=1642528800&x-signature=hyeimXP3MrVHFlmFXKbKSk1EY0g%3D',
#   'video_bitrate': 418808,
#   'video_encodedType': 'normal',
#   'video_format': 'mp4',
#   'video_videoQuality': 'normal',
#   'video_encodeUserTag': '',
#   'video_codecType': 'h264',
#   'video_definition': '480p',
#   'author_id': '6815401436291580934',
#   'author_uniqueId': '666zomey',
#   'author_nickname': 'Zomey',
#   'author_avatarThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_100x100.jpeg?x-expires=1642593600&x-signature=XEw0%2F4XnHFOulWBPfHfdzaG51sk%3D',
#   'author_avatarMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_720x720.jpeg?x-expires=1642593600&x-signature=eC19hCWKRh9HdA7B8nxa3dL1eMA%3D',
#   'author_avatarLarger': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=

#   'video_encodedType': 'normal',
#   'video_format': 'mp4',
#   'video_videoQuality': 'normal',
#   'video_encodeUserTag': '',
#   'video_codecType': 'h264',
#   'video_definition': '720p',
#   'author_id': '6879407363858793478',
#   'author_uniqueId': 'alexenzoo',
#   'author_nickname': '🐍alexenzoo🐍',
#   'author_avatarThumb': 'https://p16-sign-sg.tiktokcdn.com/aweme/100x100/tos-alisg-avt-0068/1ecc187d28f535f53f25191b20d3b7f4.jpeg?x-expires=1642593600&x-signature=9AwBZd5qpXF3iNOHBDhfxjHuAOs%3D',
#   'author_avatarMedium': 'https://p16-sign-sg.tiktokcdn.com/aweme/720x720/tos-alisg-avt-0068/1ecc187d28f535f53f25191b20d3b7f4.jpeg?x-expires=1642593600&x-signature=vYqN4GfHEkJ77t0knZF61C75oIQ%3D',
#   'author_avatarLarger': 'https://p16-sign-sg.tiktokcdn.com/aweme/1080x1080/tos-alisg-avt-0068/1ecc187d28f535f53f25191b20d3b7f4.jpeg?x-expires=1642593600&x-signature=mM8q52q5bZ4ZeGpxwChAD3A3KCw%3D',
#   'author_signature': 'Mes compagnons 🐍🦜🐠\nInstagram: @alexenzoox',
#   'author_verified': False,
#   'author_secUid': 'MS4wLjABAAAA9tlAtHtHu50wzqKK0K8G__YMLPB09ck3J-GQqhepndSaVHsy_cET3Tj_ujE3kziM',
#   'author_secret': False,
#   'author_ftc': False,
#   'author_relation': 0,
#   'author_openFavorite': False,
#   'author_commentSetting': 0,
#   'author_duetSetting': 0,
#   'author_stitchSetting': 0,
#   'author_privateAccount': False,
#   'author_isADVirtual': False,
#   'music_id': '6623108046656637701',
#   'music_title': 'Follow pepperonijoe',
#   'music_playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/1616970010746885',
#   'music_coverThumb': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/eef8d45ff6dc27842227e35aa2dc8b27~c5_100x100.jpeg?x-expires=1642593600&x-signature=fG2k0SMTyEEr%2Biut7VU2UI5IAVI%3D',
#   'music_coverMedium': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/eef8d45ff6dc27842227e35aa2dc8b27~c5_720x720.jpeg?x-expires=1642593600&x-signature=gJes0Ayw4Cnegx2f4i8oa3%2FSSxY%3D',
#   'music_coverLarge': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/eef8d45ff6dc27842227e35aa2dc8b27~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=BjyA%2BiS43hKpRd6CwhYO6Y0Bq6k%3D',
#   'music_authorName': 'Joe',
#   'music_original': True,
#   'music_duration': 16,
#   'music_album': 'pepperonijoe',
#   'stats_diggCount': 2600000,
#   'stats_shareCount': 36900,
#   'stats_commentCount': 25100,
#   'stats_playCount': 53500000,
#   'originalItem': False,
#   'officalItem': False,
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats_followingCount': 11,
#   'authorStats_followerCount': 1100000,
#   'authorStats_heartCount': 5900000,
#   'authorStats_videoCount': 229,
#   'authorStats_diggCount': 2375,
#   'authorStats_heart': 5900000,
#   'privateItem': False,
#   'duetEnabled': False,
#   'stitchEnabled': False,
#   'shareEnabled': True,
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0},
#  2: {'id': '6958430060340694278',
#   'desc': 'Happy birthday little buddy 🐍 #snake #python #birthday',
#   'createTime': 1620135755,
#   'video_id': '6958430060340694278',
#   'video_height': 1024,
#   'video_width': 576,
#   'video_duration': 20,
#   'video_ratio': '720p',
#   'video_cover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/4f9d0765d2694c2ea0c993c602630912_1620135757?x-expires=1642528800&x-signature=nBonWlzd%2F%2BpXP9pahQ2xnGG7Cw4%3D',
#   'video_originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/32bf5c5e89fe40dea457cf16fd909de7_1620135756?x-expires=1642528800&x-signature=aduGGAHOnHq9NDq0TspPhAU3Khk%3D',
#   'video_dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/57c7dd1853d2406f998d62113e679238_1620135756?x-expires=1642528800&x-signature=fu83XY%2BOIJQJf4o8UBcXsnTuPkc%3D',
#   'video_playAddr': 'https://v16-webapp.tiktok.com/29b8176d445b9bb493a11c43e7fb3d72/61e709d1/video/tos/useast2a/tos-useast2a-ve-0068c003/eafe93d235ac4da39550af4837007f13/?a=1988&br=3464&bt=1732&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=M2k0bDg7ajluNTMzNzczM0ApODg5OTtoZ2VkN2hoNTg1O2czcF9vbmhgcjVgLS1kMTZzcy0wNC5eYi81MS1eYDMvMV46Yw%3D%3D&vl=&vr=',
#   'video_downloadAddr': 'https://v16-webapp.tiktok.com/29b8176d445b9bb493a11c43e7fb3d72/61e709d1/video/tos/useast2a/tos-useast2a-ve-0068c003/eafe93d235ac4da39550af4837007f13/?a=1988&br=3464&bt=1732&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=M2k0bDg7ajluNTMzNzczM0ApODg5OTtoZ2VkN2hoNTg1O2czcF9vbmhgcjVgLS1kMTZzcy0wNC5eYi81MS1eYDMvMV46Yw%3D%3D&vl=&vr=',
#   'video_shareCover': ['',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/32bf5c5e89fe40dea457cf16fd909de7_1620135756~tplv-tiktok-play.jpeg?x-expires=1643112000&x-signature=L72WoJwWd4COdwBQJ1uZk1Xji4M%3D',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/32bf5c5e89fe40dea457cf16fd909de7_1620135756~tplv-tiktokx-share-play.jpeg?x-expires=1643112000&x-signature=UaaaxieQQz1FoGw2w0CwRdtFcHQ%3D'],
#   'video_reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/9261e2981c94793d9e81f6c7f6e3306b?x-expires=1642528800&x-signature=9duwF%2FIEAWaMmFqdeMR26MLVxWs%3D',
#   'video_bitrate': 1773607,
#   'video_encodedType': 'normal',
#   'video_format': 'mp4',
#   'video_videoQuality': 'normal',
#   'video_encodeUserTag': '',
#   'video_codecType': 'h264',
#   'video_definition': '720p',
#   'author_id': '6700343527676740613',
#   'author_uniqueId': 'thereptilezoo',
#   'author_nickname': 'The Reptile Zoo',
#   'author_avatarThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1636362969334789~c5_100x100.jpeg?x-expires=1642593600&x-signature=3ByAtYJT9H02H64O4nqlIWAURLc%3D',
#   'author_avatarMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1636362969334789~c5_720x720.jpeg?x-expires=1642593600&x-signature=PLKqYnbe3hdhi1o90TQWbQBqMlA%3D',
#   'author_avatarLarger': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1636362969334789~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=X2kiH17hu9hn3mrOZ5fYcuVSfHA%3D',
#   'author_signature': 'If it hops, wiggles, or gives your \nmom the chills, we’ve got it here!',
#   'author_verified': True,
#   'author_secUid': 'MS4wLjABAAAAqaXgkJaDFfLRDI8ZrIf-Z0rLZdtJIkxflEjhgIt5CjPJC91WcNku4vYvFPbkRpxm',
#   'author_secret': False,
#   'author_ftc': False,
#   'author_relation': 0,
#   'author_openFavorite': False,
#   'author_commentSetting': 0,
#   'author_duetSetting': 0,
#   'author_stitchSetting': 0,
#   'author_privateAccount': False,
#   'author_isADVirtual': False,
#   'music_id': '6800370585814697986',
#   'music_title': 'Intentions (Instrumental Version) [Originally Performed by Justin Bieber & Quavo]',
#   'music_playUrl': 'https://sf16-ies-music-sg.tiktokcdn.com/obj/tos-alisg-ve-2774/36ecd374967d46c3a394dab30a059cca',
#   'music_coverThumb': 'https://p9-sg.tiktokcdn.com/aweme/100x100/tos-alisg-v-2774/25636085cff34e3b97f2f24244ae8937.jpeg',
#   'music_coverMedium': 'https://p9-sg.tiktokcdn.com/aweme/200x200/tos-alisg-v-2774/25636085cff34e3b97f2f24244ae8937.jpeg',
#   'music_coverLarge': 'https://p9-sg.tiktokcdn.com/aweme/720x720/tos-alisg-v-2774/25636085cff34e3b97f2f24244ae8937.jpeg',
#   'music_authorName': 'Elliot Van Coup',
#   'music_original': False,
#   'music_duration': 60,
#   'music_album': 'Blast Thru Hits vol 3',
#   'stats_diggCount': 2200000,
#   'stats_shareCount': 16400,
#   'stats_commentCount': 9479,
#   'stats_playCount': 26900000,
#   'originalItem': False,
#   'officalItem': False,
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats_followingCount': 33,
#   'authorStats_followerCount': 11300000,
#   'authorStats_heartCount': 149600000,
#   'authorStats_videoCount': 616,
#   'authorStats_diggCount': 347,
#   'authorStats_heart': 149600000,
#   'privateItem': False,
#   'duetEnabled': False,
#   'stitchEnabled': False,
#   'shareEnabled': True,
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0},
#  3: {'id': '6980527845726604549',
#   'desc': 'lil too busy worried about snacks.. #Python #dog #snakesoftiktok #NatureTikTok',
#   'createTime': 1625280797,
#   'video_id': '6980527845726604549',
#   'video_height': 1024,
#   'video_width': 576,
#   'video_duration': 7,
#   'video_ratio': '720p',
#   'video_cover': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068
3D',
#   'music_coverMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1640873239646214~c5_720x720.jpeg?x-expires=1642593600&x-signature=eGeAw1YF9WHnx6Bvs%2BPwIXMgGwY%3D',
#   'music_coverLarge': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1640873239646214~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=mM53tsonZsvfoq3BJHoJOoMYi2k%3D',
#   'music_authorName': 'BrianBarczyk',
#   'music_original': True,
#   'music_duration': 31,
#   'music_album': '',
#   'stats_diggCount': 1700000,
#   'stats_shareCount': 21400,
#   'stats_commentCount': 5350,
#   'stats_playCount': 14200000,
#   'originalItem': False,
#   'officalItem': False,
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats_followingCount': 39,
#   'authorStats_followerCount': 3200000,
#   'authorStats_heartCount': 49500000,
#   'authorStats_videoCount': 565,
#   'authorStats_diggCount': 127,
#   'authorStats_heart': 49500000,
#   'privateItem': False,
#   'duetEnabled': False,
#   'stitchEnabled': True,
#   'shareEnabled': True,
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0},
#  6: {'id': '6998487128254483718',
#   'desc': 'computer automatically alt-tabs when door is opened. #lifehack #gaming #code #arduino #python',
#   'createTime': 1629462265,
#   'video_id': '6998487128254483718',
#   'video_height': 576,
#   'video_width': 576,
#   'video_duration': 11,
#   'video_ratio': '720p',
#   'video_cover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/d7bee0414c2645889616bd9cfdf3b926?x-expires=1642528800&x-signature=9znHbg1Y7uAwLoIpZnImOe64DDI%3D',
#   'video_originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/224f14120bc24d17b8794d7d9e0a2c55_1629462266?x-expires=1642528800&x-signature=pB1Oznb%2BHgnXWJwJWP1ek4LrEfc%3D',
#   'video_dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/066240e4082c4f8da8b3245f898adfbc_1629462266?x-expires=1642528800&x-signature=XTv%2Bb3rTeSnG795H1TArDOklOXI%3D',
#   'video_playAddr': 'https://v16-webapp.tiktok.com/7443def81e0a5632cf0bff88a105221b/61e709c8/video/tos/useast2a/tos-useast2a-ve-0068c004/69735162fbcf449fad4cdf5c0f70fce4/?a=1988&br=1526&bt=763&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=ajo1cGg6ZndzNzMzNzczM0ApZGc7Zjc4NTtmN2k1ZmU4PGdiYDVtcjQwcWNgLS1kMTZzcy8yMGIxL2JiMWItM2EyLi46Yw%3D%3D&vl=&vr=',
#   'video_downloadAddr': 'https://v16-webapp.tiktok.com/7443def81e0a5632cf0bff88a105221b/61e709c8/video/tos/useast2a/tos-useast2a-ve-0068c004/69735162fbcf449fad4cdf5c0f70fce4/?a=1988&br=1526&bt=763&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=ajo1cGg6ZndzNzMzNzczM0ApZGc7Zjc4NTtmN2k1ZmU4PGdiYDVtcjQwcWNgLS1kMTZzcy8yMGIxL2JiMWItM2EyLi46Yw%3D%3D&vl=&vr=',
#   'video_shareCover': ['',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/224f14120bc24d17b8794d7d9e0a2c55_1629462266~tplv-tiktok-play.jpeg?x-expires=1643112000&x-signature=OiObIBxJEBs735sjzkH3rv4UfUU%3D',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/224f14120bc24d17b8794d7d9e0a2c55_1629462266~tplv-tiktokx-share-play.jpeg?x-expires=1643112000&x-signature=ncYLFXoPnZxp%2FDd1lzmaZOvhJIk%3D'],
#   'video_reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/20059c1306605e6036efceb6149c1649?x-expires=1642528800&x-signature=d42ZeHKAVVG3Fg5X2rdosWi%2B%2Bbw%3D',
#   'video_bitrate': 781998,
#   'video_encodedType': 'normal',
#   'video_format': 'mp4',
#   'video_videoQuality': 'normal',
#   'video_encodeUserTag': '',
#   'video_codecType': 'h264',
#   'video_definition': '720p',
#   'author_id': '6997626915332015110',
#   'author_uniqueId': 'novelalex',
#   'author_nickname': 'Novel Alex',
#   'author_avatarThumb': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/f052076c0bd8396f04fa806b000b4ec7~c5_100x100.jpeg?x-expires=1642593600&x-signature=1g8Ju4D9CTkA4TaMhCLbWahwKB8%3D',
#   'author_avatarMedium': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/f052076c0bd8396f04fa806b000b4ec7~c5_720x720.jpeg?x-expires=1642593600&x-signature=UeW5nNNmOdISXyst%2BAvxyNcAYok%3D',
#   'author_avatarLarger': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/f052076c0bd8396f04fa806b000b4ec7~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=ivPi7ZjqaEu9x%2FTCBeBTXpRH6%2Bs%3D',
#   'author_signature': 'Why yes I am stupid, how could you tell?',
#   'author_verified': False,
#   'author_secUid': 'MS4wLjABAAAAkpjzBh6kVryLUadQHuq3UPCPe093LSeMkk_P6DFvgUGglXXccRKMFQ2GAIInQa6W',
#   'author_secret': False,
#   'author_ftc': False,
#   'author_relation': 0,
#   'author_openFavorite': False,
#   'author_commentSetting': 0,
#   'author_duetSetting': 1,
#   'author_stitchSetting': 1,
#   'author_privateAccount': False,
#   'author_isADVirtual': False,
#   'music_id': '6998486897269934853',
#   'music_title': 'original sound',
#   'music_playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/6998487019542399749.mp3',
#   'music_coverThumb': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/f052076c0bd8396f04fa806b000b4ec7~c5_100x100.jpeg?x-expires=1642593600&x-signature=1g8Ju4D9CTkA4TaMhCLbWahwKB8%3D',
#   'music_coverMedium': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/f052076c0bd8396f04fa806b000b4ec7~c5_720x720.jpeg?x-expires=1642593600&x-signature=UeW5nNNmOdISXyst%2BAvxyNcAYok%3D',
#   'music_coverLarge': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/f052076c0bd8396f04fa806b000b4ec7~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=ivPi7ZjqaEu9x%2FTCBeBTXpRH6%2Bs%3D',
#   'music_authorName': 'Novel Alex',
#   'music_original': True,
#   'music_duration': 11,
#   'music_album': '',
#   'stats_diggCount': 3200000,
#   'stats_shareCount': 85700,
#   'stats_commentCount': 26800,
#   'stats_playCount': 24400000,
#   'originalItem': False,
#   'officalItem': False,
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats_followingCount': 138,
#   'authorStats_followerCount': 48200,
#   'authorStats_heartCount': 3200000,
#   'authorStats_videoCount': 7,
#   'authorStats_diggCount': 3456,
#   'authorStats_heart': 3200000,
#   'privateItem': False,
#   'duetEnabled': True,
#   'stitchEnabled': True,
#   'shareEnabled': True,
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0},
#  7: {'id': '7015946767283850502',
#   'desc': 'You never know what’ll be in the egg 😯 #snake #python #egg',
#   'createTime': 1633527403,
#   'video_id': '7015946767283850502',
#   'video_height': 1024,
#   'video_width': 576,
#   'video_duration': 45,
#   'video_ratio': '720p',
#   'video_cover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/ab5bfd74f7da47e196cbf8b1f592100f_1633527426?x-expires=1642528800&x-signature=F2h59%2BCePlM9OJwDKVsrB5Lr70M%3D',
#   'video_originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/76a5277101f74bfb98d976d8b1f69c79_1633527405?x-expires=1642528800&x-signature=fQ%2BioFrIY0IPsSyoTSBxIwu2XUc%3D',
#   'video_dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/d18d6b3ae8b64449949f1a1cc776b741_1633527404?x-expires=1642528800&x-signature=IFDilRsA4%2F9t9qoRVYlbbJY00NI%3D',
#   'video_playAddr': 'https://v16-webapp.tiktok.com/8dfad2c5ede182cb939eb66dabe1278c/61e709ea/video/tos/useast2a/tos-useast2a-ve-0068c003/7910a2b73b8e4475bb0d59b6a9c9ecb3/?a=1988&br=3262&bt=1631&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=anNzczM6ZnV0ODMzNzczM0ApZjk5aDc4aWQ1Nzk3OjhkPGdlay1ucjRvX2JgLS1kMTZzcy0zX2AyYjNhLjIyLjRjMmM6Yw%3D%3D&vl=&vr=',
#   'video_downloadAddr': 'https://v16-webapp.tiktok.com/8dfad2c5ede182cb939eb66dabe1278c/61e709ea/video/tos/useast2a/tos-useast2a-ve-0068c003/7910a2b73b8e4475bb0d59b6a9c9ecb3/?a=1988&br=3262&bt=1631&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=anNzczM6ZnV0ODMzNzczM0ApZjk5aDc4aWQ1Nzk3OjhkPGdlay1ucjRvX2JgLS1kMTZzcy0zX2AyYjNhLjIyLjRjMmM6Yw%3D%3D&vl=&vr=',
#   'video_shareCover': ['',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/76a5277101f74bfb98d976d8b1f69c79_1633527405~tplv-tiktok-play.jpeg?x-expires=1643112000&x-signature=D0ack1K3%2FrMNCDoNeK%2FzhIT1Drk%3D',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/76a5277101f74bfb98d976d8b1f69c79_1633527405~tplv-tiktokx-share-play.jpeg?x-expires=1643112000&x-signature=DkeVZEAVWCmoHqI0IY3L5apM8Ws%3D'],
#   'video_reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/ab5bfd74f7da47e196cbf8b1f592100f_1633527426?x-expires=1642528800&x-signature=F2h59%2BCePlM9OJwDKVsrB5Lr70M%3D',
#   'video_bitrate': 1670964,
#   'video_encodedType': 'normal',
#   'video_format': 'mp4',
#   'video_videoQuality': 'normal',
#   'video_encodeUserTag': '',
#   'video_codecType': 'h264',
#   'video_definition': '720p',
#   'author_id': '6699542567460389894',
#   'author_uniqueId': 'jayprehistoricpets',
#   'author_nickname': 'Jay Brewer',
#   'author_avatarThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_100x100.jpeg?x-expires=1642593600&x-signature=V88309Rc0pemU2AtJyMl9kefW0A%3D',
#   'author_avatarMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_720x720.jpeg?x-expires=1642593600&x-signature=Qjl0uwKI7Abxt5YZsKNaf0M9Sjc%3D',
#   'author_avatarLarger': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=9K%2BWWSfEP396UH%2FusyztXbzjiO4%3D',
#   'author_signature': 'Sub to my YouTube for even more animal fun see you here on TikTok tomorrow 🤗🙌',
#   'author_verified': True,
#   'author_secUid': 'MS4wLjABAAAAKtlitna177EaY3JAgDPnjAfZj8kI-GnaM5hU9HPzaEQzcuj976k3NYbmpX9cyxc2',
#   'author_secret': False,
#   'author_ftc': False,
#   'author_relation': 0,
#   'author_openFavorite': False,
#   'author_commentSetting': 0,
#   'author_duetSetting': 0,
#   'author_stitchSetting': 0,
#   'author_privateAccount': False,
#   'author_isADVirtual': False,
#   'music_id': '7015946512425356037',
#   'music_title': 'original sound',
#   'music_playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/7015946701781404422.mp3',
#   'music_coverThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_100x100.jpeg?x-expires=1642593600&x-signature=V88309Rc0pemU2AtJyMl9kefW0A%3D',
#   'music_coverMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_720x720.jpeg?x-expires=1642593600&x-signature=Qjl0uwKI7Abxt5YZsKNaf0M9Sjc%3D',
#   'music_coverLarge': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=9K%2BWWSfEP396UH%2FusyztXbzjiO4%3D',
#   'music_authorName': 'Jay Brewer',
#   'music_original': True,
#   'music_duration': 45,
#   'music_album': '',
#   'stats_diggCount': 1300000,
#   'stats_shareCount': 3814,
#   'stats_commentCount': 8957,
#   'stats_playCount': 15200000,
#   'originalItem': False,
#   'officalItem': False,
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats_followingCount': 80,
#   'authorStats_followerCount': 17100000,
#   'authorStats_heartCount': 229400000,
#   'authorStats_videoCount': 763,
#   'authorStats_diggCount': 17100,
#   'authorStats_heart': 229400000,
#   'privateItem': False,
#   'duetEnabled': False,
#   'stitchEnabled': False,
#   'shareEnabled': True,
#   'stickersOnItem': [{'stickerType': 4,
#     'stickerText': ['What’s in \nthe egg 🥚 ']}],
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0},
#  8: {'id': '6933762096479866118',
#   'desc': 'THEY SCARED😂@jmontt @zwifty2k #viral #foryoupage #fyp #fypシ #funny #snake #prank #python #dangerous #nocapz #prankgonewrong',
#   'createTime': 1614392308,
#   'video_id': '6933762096479866118',
#   'video_height': 1024,
#   'video_width': 576,
#   'video_duration': 56,
#   'video_ratio': '720p',
#   'video_cover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/9409313714284192bed868f246d5fdf8?x-expires=1642528800&x-signature=V6IHvNci2rgA9yWFPvjllO3aR%2B8%3D',
#   'video_originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/3184d0b9d3b64516a7cd8471d2bc7e2d_1614392311?x-expires=1642528800&x-signature=%2BmVq6fwOvLWqzxKZ5n9gbYb7psQ%3D',
#   'video_dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/68298694322b437cb2a79d7329f98005_1614392311?x-expires=1642528800&x-signature=Ewn3v0HlHSEJ3j8oCo588ZAagqQ%3D',
#   'video_playAddr': 'https://v16-webapp.tiktok.com/b5a216c4f5b8ed012fcd12417e48039b/61e709f5/video/tos/useast2a/tos-useast2a-ve-0068c003/452f266fb3bf458f8c61cbdd7028c5b8/?a=1988&br=1148&bt=574&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=ajY7cnhrc2x0MzMzNTczM0ApOmloPGZkMzs7NzVnaTRlZ2czb3EvNDZpa3BgLS1eMTZzc2FgNWIyL2EzYjAtM15gMl86Yw%3D%3D&vl=&vr=',
#   'video_downloadAddr': 'https://v16-webapp.tiktok.com/b5a216c4f5b8ed012fcd12417e48039b/61e709f5/video/tos/useast2a/tos-useast2a-ve-0068c003/452f266fb3bf458f8c61cbdd7028c5b8/?a=1988&br=1148&bt=574&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=ajY7cnhrc2x0MzMzNTczM0ApOmloPGZkMzs7NzVnaTRlZ2czb3EvNDZpa3BgLS1eMTZzc2FgNWIyL2EzYjAtM15gMl86Yw%3D%3D&vl=&vr=',
#   'video_shareCover': ['',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/3184d0b9d3b64516a7cd8471d2bc7e2d_1614392311~tplv-tiktok-play.jpeg?x-expires=1643112000&x-signature=8qHaBIaymS4Qyja8YukV8bsuap4%3D',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/3184d0b9d3b64516a7cd8471d2bc7e2d_1614392311~tplv-tiktokx-share-play.jpeg?x-expires=1643112000&x-signature=lYAFIOYsHHYY%2F2elguEZBVohY90%3D'],
#   'video_reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/9409313714284192bed868f246d5fdf8?x-expires=1642528800&x-signature=V6IHvNci2rgA9yWFPvjllO3aR%2B8%3D',
#   'video_bitrate': 588379,
#   'video_encodedType': 'normal',
#   'video_format': 'mp4',
#   'video_videoQuality': 'normal',
#   'video_encodeUserTag': '',
#   'video_codecType': 'h264',
#   'video_definition': '720p',
#   'author_id': '6794477622329246726',
#   'author_uniqueId': 'nocapzz',
#   'author_nickname': 'NoCapZ',
#   'author_avatarThumb': 'https://p16-sign.tiktokcdn-us.com/tos-useast5-avt-0068-tx/c64a02b16eacb7619461c5b19aa2d133~c5_100x100.jpeg?x-expires=1642593600&x-signature=H1VLEThbk78GcAVK3QEAfZu36QQ%3D',
#   'author_avatarMedium': 'https://p16-sign.tiktokcdn-us.com/tos-useast5-avt-0068-tx/c64a02b16eacb7619461c5b19aa2d133~c5_720x720.jpeg?x-expires=1642593600&x-signature=fMWFfe0QKkhKuDUCIdjPzqujZL8%3D',
#   'author_avatarLarger': 'https://p16-sign.tiktokcdn-us.com/tos-useast5-avt-0068-tx/c64a02b16eacb7619461c5b19aa2d133~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=ysEYWMA9kVSyVcqBcLbRyTJIuBk%3D',
#   'author_signature': 'FOLLOW MY INSTAGRAM🖤\nROCK HILL📍\n25K ON YOUTUBE📈\nDM FOR ANY BUSINESS✍️',
#   'author_verified': False,
#   'author_secUid': 'MS4wLjABAAAAkHALWYLlTP4TZRq8zkSjCYez1uch8RQDPbW3egHYytNOQ0iIYxuVa0r-FaF162pf',
#   'author_secret': False,
#   'author_ftc': False,
#   'author_relation': 0,
#   'author_openFavorite': False,
#   'author_commentSetting': 0,
#   'author_duetSetting': 0,
#   'author_stitchSetting': 0,
#   'author_privateAccount': False,
#   'author_isADVirtual': False,
#   'music_id': '6933762080180898565',
#   'music_title': 'original sound',
#   'music_playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/6933762115539159814.mp3',
#   'music_coverThumb': 'https://p16-sign.tiktokcdn-us.com/tos-useast5-avt-0068-tx/c64a02b16eacb7619461c5b19aa2d133~c5_100x100.jpeg?x-expires=1642593600&x-signature=H1VLEThbk78GcAVK3QEAfZu36QQ%3D',
#   'music_coverMedium': 'https://p16-sign.tiktokcdn-us.com/tos-useast5-avt-0068-tx/c64a02b16eacb7619461c5b19aa2d133~c5_720x720.jpeg?x-expires=1642593600&x-signature=fMWFfe0QKkhKuDUCIdjPzqujZL8%3D',
#   'music_coverLarge': 'https://p16-sign.tiktokcdn-us.com/tos-useast5-avt-0068-tx/c64a02b16eacb7619461c5b19aa2d133~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=ysEYWMA9kVSyVcqBcLbRyTJIuBk%3D',
#   'music_authorName': 'NoCapZ',
#   'music_original': True,
#   'music_duration': 56,
#   'music_album': '',
#   'stats_diggCount': 1300000,
#   'stats_shareCount': 13000,
#   'stats_commentCount': 4219,
#   'stats_playCount': 6100000,
#   'originalItem': False,
#   'officalItem': False,
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats_followingCount': 1,
#   'authorStats_followerCount': 320600,
#   'authorStats_heartCount': 7700000,
#   'authorStats_videoCount': 492,
#   'authorStats_diggCount': 18900,
#   'authorStats_heart': 7700000,
#   'privateItem': False,
#   'duetEnabled': True,
#   'stitchEnabled': True,
#   'shareEnabled': True,
#   'stickersOnItem': [{'stickerType': 4,
#     'stickerText': ['I TOLD MY FRIENDS THAT I LOST MY “SNAKE” IN THE CAR😳',
#      'PART 1',
#      'THEY HEART DROPPED😱']}],
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0},
#  9: {'id': '7019396141955517701',
#   'desc': 'She a lil… dramatic #snakes #snake #ballpython #python #cute #reptile #silly #lol #bp #snakesoftiktok #IKnowWhatYouDid',
#   'createTime': 1634330523,
# ...
#   'video_originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/eb1c092cff22449a8223826b4c9fe3b9_1636987104?x-expires=1642528800&x-signature=FXl8znl9ESSTBakU3QGHr8g7ZwQ%3D',
#   'video_dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/6d539263c4a5454e9fc2506daf3ee9e6_1636987105?x-expires=1642528800&x-signature=F8tGAJS%2BMSr5b2asVksDUZUkXkw%3D',
#   'video_playAddr': 'https://v16-webapp.tiktok.com/ba93f643a2b6924d5f0485616e285367/61e709f0/video/tos/useast2a/tos-useast2a-ve-0068c003/a0aa29059af84f67874e619a43fa9ecb/?a=1988&br=3184&bt=1592&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=M2Z5NDc6Zng5OTMzNzczM0ApPDtkNzdlaGRnN2c1OGczZ2dyNl9lcjRvczZgLS1kMTZzc19fYTRgNGAxNDQuMV8tYC46Yw%3D%3D&vl=&vr=',
#   'video_downloadAddr': 'https://v16-webapp.tiktok.com/ba93f643a2b6924d5f0485616e285367/61e709f0/video/tos/useast2a/tos-useast2a-ve-0068c003/a0aa29059af84f67874e619a43fa9ecb/?a=1988&br=3184&bt=1592&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=M2Z5NDc6Zng5OTMzNzczM0ApPDtkNzdlaGRnN2c1OGczZ2dyNl9lcjRvczZgLS1kMTZzc19fYTRgNGAxNDQuMV8tYC46Yw%3D%3D&vl=&vr=',
#   'video_shareCover': ['',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/eb1c092cff22449a8223826b4c9fe3b9_1636987104~tplv-tiktok-play.jpeg?x-expires=1643112000&x-signature=1w2VAgC5AAx3ZodphMOCNY2z29k%3D',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/eb1c092cff22449a8223826b4c9fe3b9_1636987104~tplv-tiktokx-share-play.jpeg?x-expires=1643112000&x-signature=WaM3AMbzuFt0xI3A%2BaFeju6cQ6Q%3D'],
#   'video_reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/e4fd7764e1bcf871f0a41b5a9da16910?x-expires=1642528800&x-signature=3tG1YvNs2PQ1o8KmeJH2ksyZCEg%3D',
#   'video_bitrate': 1630585,
#   'video_encodedType': 'normal',
#   'video_format': 'mp4',
#   'video_videoQuality': 'normal',
#   'video_encodeUserTag': '',
#   'video_codecType': 'h264',
#   'video_definition': '720p',
#   'author_id': '6699542567460389894',
#   'author_uniqueId': 'jayprehistoricpets',
#   'author_nickname': 'Jay Brewer',
#   'author_avatarThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_100x100.jpeg?x-expires=1642593600&x-signature=V88309Rc0pemU2AtJyMl9kefW0A%3D',
#   'author_avatarMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_720x720.jpeg?x-expires=1642593600&x-signature=Qjl0uwKI7Abxt5YZsKNaf0M9Sjc%3D',
#   'author_avatarLarger': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=9K%2BWWSfEP396UH%2FusyztXbzjiO4%3D',
#   'author_signature': 'Sub to my YouTube for even more animal fun see you here on TikTok tomorrow 🤗🙌',
#   'author_verified': True,
#   'author_secUid': 'MS4wLjABAAAAKtlitna177EaY3JAgDPnjAfZj8kI-GnaM5hU9HPzaEQzcuj976k3NYbmpX9cyxc2',
#   'author_secret': False,
#   'author_ftc': False,
#   'author_relation': 0,
#   'author_openFavorite': False,
#   'author_commentSetting': 0,
#   'author_duetSetting': 0,
#   'author_stitchSetting': 0,
#   'author_privateAccount': False,
#   'author_isADVirtual': False,
#   'music_id': '7030805915611728645',
#   'music_title': 'original sound',
#   'music_playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/7030805981353265926.mp3',
#   'music_coverThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_100x100.jpeg?x-expires=1642593600&x-signature=V88309Rc0pemU2AtJyMl9kefW0A%3D',
#   'music_coverMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_720x720.jpeg?x-expires=1642593600&x-signature=Qjl0uwKI7Abxt5YZsKNaf0M9Sjc%3D',
#   'music_coverLarge': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=9K%2BWWSfEP396UH%2FusyztXbzjiO4%3D',
#   'music_authorName': 'Jay Brewer',
#   'music_original': True,
#   'music_duration': 51,
#   'music_album': '',
#   'stats_diggCount': 625300,
#   'stats_shareCount': 4649,
#   'stats_commentCount': 3035,
#   'stats_playCount': 7900000,
#   'originalItem': False,
#   'officalItem': False,
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats_followingCount': 80,
#   'authorStats_followerCount': 17100000,
#   'authorStats_heartCount': 229400000,
#   'authorStats_videoCount': 763,
#   'authorStats_diggCount': 17100,
#   'authorStats_heart': 229400000,
#   'privateItem': False,
#   'duetEnabled': False,
#   'stitchEnabled': False,
#   'shareEnabled': True,
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0},
#  28: {'id': '6920302329358978310',
#   'desc': '🐍🐍 Nasza największa pycia 😈 #molt #gadolandreda #gadoland #reda #noise #snake #omg #foryou #reptile #listen #python',
#   'createTime': 1611258459,
#   'video_id': '6920302329358978310',
#   'video_height': 960,
#   'video_width': 540,
#   'video_duration': 12,
#   'video_ratio': '720p',
#   'video_cover': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/90d4dda33d64429fb8e09c40e39d8b31_1611258462~tplv-dmt-logom:tos-maliva-p-0000/ada0d60c22184f35b3bb7092441a96fc.image?x-expires=1642528800&x-signature=XY4W2HjBXocChz1dptRmloFXbDo%3D',
#   'video_originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/f47cc650e14144ac86559f5320f5a8cc_1611258461?x-expires=1642528800&x-signature=T53frDx9E6TBTUaB1gcZrJTQ8uk%3D',
#   'video_dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/8409cdbf3bfd4042bf566355c3ad9c45_1611258462?x-expires=1642528800&x-signature=u5zO6njxY0EsZ9M7aR%2ByAe1CKQk%3D',
#   'video_playAddr': 'https://v16-webapp.tiktok.com/5a5069f28555c41b5a221f99f5933248/61e709c8/video/tos/useast2a/tos-useast2a-pve-0068/99c711d53fa44c619299208ed95636f3/?a=1988&br=4198&bt=2099&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=Mzp4OmR3bzx3MzMzOjczM0ApaTM1NGZnZGQ5N2c4NWRlO2cvMm9zLWhfaDFgLS1iMTZzc14uLTQtMmJjYi0xXmA2NS46Yw%3D%3D&vl=&vr=',
#   'video_downloadAddr': 'https://v16-webapp.tiktok.com/5a5069f28555c41b5a221f99f5933248/61e709c8/video/tos/useast2a/tos-useast2a-pve-0068/99c711d53fa44c619299208ed95636f3/?a=1988&br=4198&bt=2099&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=Mzp4OmR3bzx3MzMzOjczM0ApaTM1NGZnZGQ5N2c4NWRlO2cvMm9zLWhfaDFgLS1iMTZzc14uLTQtMmJjYi0xXmA2NS46Yw%3D%3D&vl=&vr=',
#   'video_shareCover': ['',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/f47cc650e14144ac86559f5320f5a8cc_1611258461~tplv-tiktok-play.jpeg?x-expires=1643112000&x-signature=aNCsHL1mbeWg3%2FXDME5VGToYV2Q%3D',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/f47cc650e14144ac86559f5320f5a8cc_1611258461~tplv-tiktokx-share-play.jpeg?x-expires=1643112000&x-signature=0ml1aj9SHhMP77qEYHBzsZBcYdw%3D'],
#   'video_reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/90d4dda33d64429fb8e09c40e39d8b31_1611258462?x-expires=1642528800&x-signature=mYWXLmzgRDtEDFtG3vvwIAXih6s%3D',
#   'video_bitrate': 2149770,
#   'video_encodedType': 'normal',
#   'video_format': 'mp4',
#   'video_videoQuality': 'normal',
#   'video_encodeUserTag': '',
#   'video_codecType': 'h264',
#   'video_definition': '720p',
#   'author_id': '6824865113461605382',
#   'author_uniqueId': 'gadoland_reda',
#   'author_nickname': 'Gadoland Reda 🐍🦎🐊',
#   'author_avatarThumb': 'https://p77-sign-va.tiktokcdn.com/musically-maliva-obj/1666228176530437~c5_100x100.jpeg?x-expires=1642593600&x-signature=D5ZCaFcp5rmK9VUeFMWnZ2P%2FwFQ%3D',
#   'author_avatarMedium': 'https://p77-sign-va.tiktokcdn.com/musically-maliva-obj/1666228176530437~c5_720x720.jpeg?x-expires=1642593600&x-signature=ylLVRjg3duJG7Y7jyi2fWox2Ims%3D',
#   'author_avatarLarger': 'https://p77-sign-va.tiktokcdn.com/musically-maliva-obj/1666228176530437~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=eG0ArJ%2BmYZccpr%2FeAmbQwipZuMo%3D',
#   'author_signature': 'Life with exotic animals\nKarnawał 5-6 lutego 2022 ! \n📩Gadoland@aquaparkreda.pl',
#   'author_verified': True,
#   'author_secUid': 'MS4wLjABAAAAklrDQLWlZI8RIBXXV5UNmo6FGH-amE-eLlwb3mTdBRcKtdObWUkgsjGyc1VM8vQd',
#   'author_secret': False,
#   'author_ftc': False,
#   'author_relation': 0,
#   'author_openFavorite': False,
#   'author_commentSetting': 0,
#   'author_duetSetting': 0,
#   'author_stitchSetting': 0,
#   'author_privateAccount': False,
#   'author_isADVirtual': False,
#   'music_id': '6920302341254056709',
#   'music_title': 'dźwięk oryginalny',
#   'music_playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/6920302317438864134.mp3',
#   'music_coverThumb': 'https://p77-sign-va.tiktokcdn.com/musically-maliva-obj/1666228176530437~c5_100x100.jpeg?x-expires=1642593600&x-signature=D5ZCaFcp5rmK9VUeFMWnZ2P%2FwFQ%3D',
#   'music_coverMedium': 'https://p77-sign-va.tiktokcdn.com/musically-maliva-obj/1666228176530437~c5_720x720.jpeg?x-expires=1642593600&x-signature=ylLVRjg3duJG7Y7jyi2fWox2Ims%3D',
#   'music_coverLarge': 'https://p77-sign-va.tiktokcdn.com/musically-maliva-obj/1666228176530437~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=eG0ArJ%2BmYZccpr%2FeAmbQwipZuMo%3D',
#   'music_authorName': 'Gadoland Reda 🐍🦎🐊',
#   'music_original': True,
#   'music_duration': 11,
#   'music_album': '',
#   'stats_diggCount': 617300,
#   'stats_shareCount': 12300,
#   'stats_commentCount': 10700,
#   'stats_playCount': 12300000,
#   'originalItem': False,
#   'officalItem': False,
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats_followingCount': 0,
#   'authorStats_followerCount': 314100,
#   'authorStats_heartCount': 4600000,
#   'authorStats_videoCount': 220,
#   'authorStats_diggCount': 836,
#   'authorStats_heart': 4600000,
#   'privateItem': False,
#   'duetEnabled': False,
#   'stitchEnabled': False,
#   'shareEnabled': True,
#   'stickersOnItem': [{'stickerType': 4,
#     'stickerText': ['Podoba Ci się ten dźwięk ?😬']},
#    {'stickerType': 9, 'stickerText': ['Musisz posłuchać ❗️']}],
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0},
#  29: {'id': '6823157143621979398',
#   'desc': 'PASS THE REPTILE!!! 🐍🦎🕷🦂🐊🐢🐸#margothebeardie #reptile #python #may4th',
#   'createTime': 1588640072,
#   'video_id': '6823157143621979398',
#   'video_height': 1024,
#   'video_width': 576,
#   'video_duration': 55,
#   'video_ratio': '720p',
#   'video_cover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/a4ec965371274d8abd6b235bcc0e15dc?x-expires=1642528800&x-signature=Mf778iQLSiSeGzMTUtA2VDxfqL8%3D',
#   'video_originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/f8f040b2d3db4b8aa750fe9de3cc192c_1588640075?x-expires=1642528800&x-signature=lT%2BPJ4CVxqekO4NCZYhO3biEPy0%3D',
#   'video_dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/7fa1b48c458c4c91a6fe8a765c9edef8_1588640074?x-expires=1642528800&x-signature=9OzljjBovl%2Bv13dpoa0%2BaLjcRIs%3D',
#   'video_playAddr': 'https://v16-webapp.tiktok.com/804fc6262f95bed699537653cb5ae232/61e709f4/video/tos/useast2a/tos-useast2a-ve-0068c004/e10b30d200754b45a3d50b81cc5e2fb6/?a=1988&br=2472&bt=1236&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=M3g8OjNveGpldDMzNzczM0ApPDM5NjY5ZWQ6N2c8Z2U1OGdybGA1Y25eZmxfLS1hMTZzczBhMDZiNDVjNGEzNC41LWE6Yw%3D%3D&vl=&vr=',
#   'video_downloadAddr': 'https://v16-webapp.tiktok.com/804fc6262f95bed699537653cb5ae232/61e709f4/video/tos/useast2a/tos-useast2a-ve-0068c004/e10b30d200754b45a3d50b81cc5e2fb6/?a=1988&br=2472&bt=1236&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3CTnz7Th74vylXq&l=20220118124101010245040106012305C1&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=M3g8OjNveGpldDMzNzczM0ApPDM5NjY5ZWQ6N2c8Z2U1OGdybGA1Y25eZmxfLS1hMTZzczBhMDZiNDVjNGEzNC41LWE6Yw%3D%3D&vl=&vr=',
#   'video_shareCover': ['',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/f8f040b2d3db4b8aa750fe9de3cc192c_1588640075~tplv-tiktok-play.jpeg?x-expires=1643112000&x-signature=fWefPWdwysJEvp0DkidwVB9K7aE%3D',
#    'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/f8f040b2d3db4b8aa750fe9de3cc192c_1588640075~tplv-tiktokx-share-play.jpeg?x-expires=1643112000&x-signature=%2BxBsnRVgi%2FgGO6lomjiQRFRUpMM%3D'],
#   'video_reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/a4ec965371274d8abd6b235bcc0e15dc?x-expires=1642528800&x-signature=Mf778iQLSiSeGzMTUtA2VDxfqL8%3D',
#   'video_bitrate': 1266062,
#   'video_encodedType': 'normal',
#   'video_format': 'mp4',
#   'video_videoQuality': 'normal',
#   'video_encodeUserTag': '',
#   'video_codecType': 'h264',
#   'video_definition': '720p',
#   'author_id': '6399531',
#   'author_uniqueId': '_hawke_',
#   'author_nickname': 'R. Hawke',
#   'author_avatarThumb': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/4f58701cc9fa08fa2b1f79eebc2913c5~c5_100x100.jpeg?x-expires=1642593600&x-signature=nwMDyMr6axCy%2FHN5inO3RNYlhQU%3D',
#   'author_avatarMedium': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/4f58701cc9fa08fa2b1f79eebc2913c5~c5_720x720.jpeg?x-expires=1642593600&x-signature=SLLLPZEXgORuw9y11%2FVAFt%2Fc%2FNo%3D',
#   'author_avatarLarger': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/4f58701cc9fa08fa2b1f79eebc2913c5~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=1ZDScQS5lOiVKHpwn%2B%2BjeFtrPsE%3D',
#   'author_signature': 'Sc ~ ryleigh.hawke \n19 they/them♌️\n🦎I am fairhopeherps🦎\n🔞+ insta bio\nNYC',
#   'author_verified': False,
#   'author_secUid': 'MS4wLjABAAAAle9vDQB0W2czKI755FRiGUgrqJaYstezpdwwh5wDPgs',
#   'author_secret': False,
#   'author_ftc': False,
#   'author_relation': 0,
#   'author_openFavorite': False,
#   'author_commentSetting': 0,
#   'author_duetSetting': 0,
#   'author_stitchSetting': 0,
#   'author_privateAccount': False,
#   'author_isADVirtual': False,
#   'music_id': '6821305092663282437',
#   'music_title': 'original sound',
#   'music_playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/8a1b3f8a1d55c7fdba96e27f575816a1.mp3',
#   'music_coverThumb': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/3207247adc7dbd388ec3e98c40faeb04~c5_100x100.jpeg?x-expires=1642593600&x-signature=K83I9CPg%2BLlJBiqezsWpIn6Eee4%3D',
#   'music_coverMedium': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/3207247adc7dbd388ec3e98c40faeb04~c5_720x720.jpeg?x-expires=1642593600&x-signature=RLJigMZ1PyU4%2BI7jb%2BIF8Hkao%2BY%3D',
#   'music_coverLarge': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/3207247adc7dbd388ec3e98c40faeb04~c5_1080x1080.jpeg?x-expires=1642593600&x-signature=q5fXc8tbgwiaNnJUCODNeRLKUEI%3D',
#   'music_authorName': 'cort',
#   'music_original': True,
#   'music_duration': 59,
#   'music_album': '',
#   'stats_diggCount': 604200,
#   'stats_shareCount': 1758,
#   'stats_commentCount': 5366,
#   'stats_playCount': 2200000,
#   'warnInfo': [{'text': 'Participating in this activity could result in you or others getting hurt.',
#     'type': 1,
#     'lang': 'en',
#     'key': 'aweme_risk_info_potential_danger'}],
#   'originalItem': False,
#   'officalItem': False,
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats_followingCount': 1065,
#   'authorStats_followerCount': 6000000,
#   'authorStats_heartCount': 311800000,
#   'authorStats_videoCount': 1617,
#   'authorStats_diggCount': 204800,
#   'authorStats_heart': 311800000,
#   'privateItem': False,
#   'duetEnabled': True,
#   'stitchEnabled': True,
#   'shareEnabled': True,
#   'stickersOnItem': [{'stickerType': 4, 'stickerText': ['PASS THE REPTILE']}],
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0}}

# %%
type(flattened_data)
# Out:
# dict

# %% [markdown]
# # Test out Output

# %%
df_test = pd.DataFrame.from_dict(flattened_data, orient='index')
df_test.head()
# Out:
#                     id                                               desc  \
# 0  6914157190987271430  Oh Julius 😅 "Julius the Python" on YouTube #ju...
# 1  6909838234151423234  stain.. Petit python banana..😍#fyp  #ballpytho...
# 2  6958430060340694278  Happy birthday little buddy 🐍 #snake #python #...
# 3  6980527845726604549  lil too busy worried about snacks.. #Python #d...
# 4  6840796191161175302  Check out this baby python! Did you kno their ...
#
#    createTime             video_id  video_height  video_width  video_duration  \
# 0  1609827712  6914157190987271430           480          640               9
# 1  1608822085  6909838234151423234           960          540              15
# 2  1620135755  6958430060340694278          1024          576              20
# 3  1625280797  6980527845726604549          1024          576               7
# 4  1592746983  6840796191161175302          1024          576              18
#
#   video_ratio                                        video_cover  \
# 0        480p  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 1        720p  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 2        720p  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 3        720p  https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 4        720p  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
#
#                                    video_originCover  ... privateItem  \
# 0  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 1  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...       False
# 2  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 3  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 4  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
#
#   duetEnabled stitchEnabled shareEnabled  \
# 0        True          True         True
# 1       False         False         True
# 2       False         False         True
# 3        True          True         True
# 4        True          True         True
#
#                                       stickersOnItem   isAd duetDisplay  \
# 0  [{'stickerType': 4, 'stickerText': ['That time...  False           0
# 1                                                NaN  False           0
# 2                                                NaN  False           0
# 3  [{'stickerType': 9, 'stickerText': ['Dog steps...  False           0
# 4                                                NaN  False           0
#
#   stitchDisplay warnInfo effectStickers
# 0             0      NaN            NaN
# 1             0      NaN            NaN
# 2             0      NaN            NaN
# 3             0      NaN            NaN
# 4             0      NaN            NaN
#
# [5 rows x 79 columns]

# %%
df_test.to_csv('analytics.csv')

# %% [markdown]
# ## Testing

# %%
from TikTokApi import TikTokApi
import pandas as pd

# %%
with TikTokApi() as api:
    tag = api.hashtag(name="syedsaddiq")
    print(tag.info())
    print()

    # sum = 0
    #
    # for video in tag.videos(count=31):
    #     print(video.as_dict)
    #     print()
    #     sum = sum + 1
    #
    # print(sum)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 with TikTokApi() as api:
#       2     tag = api.hashtag(name="syedsaddiq")
#       3     print(tag.info())
#
# File ~\PycharmProjects\TikTokAnalytics\venv\lib\site-packages\TikTokApi\tiktok.py:159, in TikTokApi.__init__(self, logging_level, request_delay, custom_device_id, generate_static_device_id, custom_verify_fp, use_test_endpoints, proxy, executable_path, *args, **kwargs)
#     156 self.logger.setLevel(logging_level)
#     158 with _thread_lock:
# --> 159     self._initialize(
#     160         request_delay=request_delay,
#     161         custom_device_id=custom_device_id,
#     162         generate_static_device_id=generate_static_device_id,
#     163         custom_verify_fp=custom_verify_fp,
#     164         use_test_endpoints=use_test_endpoints,
#     165         proxy=proxy,
#     166         executable_path=executable_path,
#     167         *args,
#     168         **kwargs,
#     169     )
#
# File ~\PycharmProjects\TikTokAnalytics\venv\lib\site-packages\TikTokApi\tiktok.py:205, in TikTokApi._initialize(self, **kwargs)
#     200     self._custom_device_id = "".join(
#     201         random.choice(string.digits) for num in range(19)
#     202     )
#     204 if self._signer_url is None:
# --> 205     self._browser = asyncio.get_event_loop().run_until_complete(
#     206         asyncio.gather(browser.create(**kwargs))
#     207     )[0]
#     209     self._user_agent = self._browser.user_agent
#     211 try:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py:622, in BaseEventLoop.run_until_complete(self, future)
#     611 """Run until the Future is done.
#     612
#     613 If the argument is a coroutine, it is wrapped in a Task.
#    (...)
#     619 Return the Future's result, or raise its exception.
#     620 """
#     621 self._check_closed()
# --> 622 self._check_running()
#     624 new_task = not futures.isfuture(future)
#     625 future = tasks.ensure_future(future, loop=self)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py:582, in BaseEventLoop._check_running(self)
#     580 def _check_running(self):
#     581     if self.is_running():
# --> 582         raise RuntimeError('This event loop is already running')
#     583     if events._get_running_loop() is not None:
#     584         raise RuntimeError(
#     585             'Cannot run the event loop while another loop is running')
#
# RuntimeError: This event loop is already running
